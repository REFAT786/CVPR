# %%
import numpy as np
import matplotlib.pyplot as plt

def twospirals(n_points, noise=.5):
    
    n = np.sqrt(np.random.rand(n_points,1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), 
            np.hstack((np.zeros(n_points),np.ones(n_points))))

X, y = twospirals(1000)

plt.title('training set')
plt.plot(X[y==0,0], X[y==0,1], '.', label='class 1')
plt.plot(X[y==1,0], X[y==1,1], '.', label='class 2')
plt.legend()
plt.show()
XX=np.squeeze(np.asarray(X))
YY=np.squeeze(np.asarray(y))

print(XX)
print(YY)
# Out:
# [[  2.60417953  -3.17450032]
#  [ -6.89052613  11.59504324]
#  [ -0.73561246 -10.90229065]
#  ...
#  [ 11.48809278  -6.3681049 ]
#  [  0.5621609   -7.83692924]
#  [ -0.89321193  -8.21985577]]
# [0. 0. 0. ... 1. 1. 1.]

# %%
X=XX
Y=YY
class NeuralNetwork(object):
    def __init__(self):
        inputLayerNeurons = 2
        hiddenLayerNeurons = 10
        outLayerNeurons = 1
        
        self.learning_rate = 0.2
        self.W_HI = np.random.randn(inputLayerNeurons, hiddenLayerNeurons)
        self.W_OH = np.random.randn(hiddenLayerNeurons, outLayerNeurons)
        
    def TanH(self, x, der=False):
        if der == True:
            return 1- x**2
        else:
            return (np.exp(2*x) - 1) / (np.exp(2*x) + 1)
        
    def feedForward(self, X):
        hidden_input = np.dot(X, self.W_HI)
        self.hidden_output = self.TanH(hidden_input)
        
        output_input = np.dot(self.hidden_output, self.W_OH)
        pred = self.TanH(output_input)
        return pred
        
    def backPropagation(self, X, Y, pred):
        output_error = Y - pred
        output_delta = self.learning_rate * output_error * self.TanH(pred, der=True)
        
        hidden_error = output_delta.dot(self.W_OH.T)
        hidden_delta = self.learning_rate * hidden_error * self.TanH(self.hidden_output, der=True)
        
        self.W_HI += X.T.dot(hidden_delta)
        self.W_OH += self.hidden_output.T.dot(output_delta)
        
    def train(self, X, Y):
        output = self.feedForward(X)
        self.backPropagation(X,Y,output)

# %%
NN = NeuralNetwork()

err = []
for i in range(10000):
    NN.train(X,Y)
    err.append(np.mean(np.square(Y - NN.feedForward(X))))

plt.plot(err)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10108/348166544.py in <module>
#       3 err = []
#       4 for i in range(10000):
# ----> 5     NN.train(X,Y)
#       6     err.append(np.mean(np.square(Y - NN.feedForward(X))))
#       7
#
# ~\AppData\Local\Temp/ipykernel_10108/2598797381.py in train(self, X, Y)
#      37     def train(self, X, Y):
#      38         output = self.feedForward(X)
# ---> 39         self.backPropagation(X,Y,output)
#
# ~\AppData\Local\Temp/ipykernel_10108/2598797381.py in backPropagation(self, X, Y, pred)
#      29         output_delta = self.learning_rate * output_error * self.TanH(pred, der=True)
#      30
# ---> 31         hidden_error = output_delta.dot(self.W_OH.T)
#      32         hidden_delta = self.learning_rate * hidden_error * self.TanH(self.hidden_output, der=True)
#      33
#
# ValueError: shapes (2000,2000) and (1,10) not aligned: 2000 (dim 1) != 1 (dim 0)

# %%
##RelU
X=XX
Y=YY
class NeuralNetwork(object):
    def __init__(self):
        inputLayerNeurons = 2
        hiddenLayerNeurons = 10
        outLayerNeurons = 1
        
        self.learning_rate = 0.2
        self.W_HI = np.random.randn(inputLayerNeurons, hiddenLayerNeurons)
        self.W_OH = np.random.randn(hiddenLayerNeurons, outLayerNeurons)
        
    def RelU(self, x, der=False):
        if der == True:
            return 1- x**2
        else:
            return list(map(lambda a: a if a>=0 else 0, x))
        
    def feedForward(self, X):
        hidden_input = np.dot(X, self.W_HI)
        self.hidden_output = self.RelU(hidden_input)
        
        output_input = np.dot(self.hidden_output, self.W_OH)
        pred = self.RelU(output_input)
        return pred
        
    def backPropagation(self, X, Y, pred):
        output_error = Y - pred
        output_delta = self.learning_rate * output_error * self.RelU(pred, der=True)
        
        hidden_error = output_delta.dot(self.W_OH.T)
        hidden_delta = self.learning_rate * hidden_error * self.RelU(self.hidden_output, der=True)
        
        self.W_HI += X.T.dot(hidden_delta)
        self.W_OH += self.hidden_output.T.dot(output_delta)
        
    def train(self, X, Y):
        output = self.feedForward(X)
        self.backPropagation(X,Y,output)

# %%
NN = NeuralNetwork()

err = []
for i in range(10000):
    NN.train(X,Y)
    err.append(np.mean(np.square(Y - NN.feedForward(X))))

plt.plot(err)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10108/348166544.py in <module>
#       3 err = []
#       4 for i in range(10000):
# ----> 5     NN.train(X,Y)
#       6     err.append(np.mean(np.square(Y - NN.feedForward(X))))
#       7
#
# ~\AppData\Local\Temp/ipykernel_10108/2708995526.py in train(self, X, Y)
#      37
#      38     def train(self, X, Y):
# ---> 39         output = self.feedForward(X)
#      40         self.backPropagation(X,Y,output)
#
# ~\AppData\Local\Temp/ipykernel_10108/2708995526.py in feedForward(self, X)
#      20     def feedForward(self, X):
#      21         hidden_input = np.dot(X, self.W_HI)
# ---> 22         self.hidden_output = self.RelU(hidden_input)
#      23
#      24         output_input = np.dot(self.hidden_output, self.W_OH)
#
# ~\AppData\Local\Temp/ipykernel_10108/2708995526.py in RelU(self, x, der)
#      16             return 1- x**2
#      17         else:
# ---> 18             return list(map(lambda a: a if a>=0 else 0, x))
#      19
#      20     def feedForward(self, X):
#
# ~\AppData\Local\Temp/ipykernel_10108/2708995526.py in <lambda>(a)
#      16             return 1- x**2
#      17         else:
# ---> 18             return list(map(lambda a: a if a>=0 else 0, x))
#      19
#      20     def feedForward(self, X):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
